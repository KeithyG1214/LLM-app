# %%
import os
print(os.getenv("GROQ_API_KEY"))
# Out:
# None

# %%
import streamlit as staticmethod
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as staticmethod
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
import streamlit as st

try:
    GROQ_API_KEY = st.secrets["GROQ_API_KEY"]
except Exception as e:
    st.error(f"Missing API key: {e}")
    st.stop()

st.title("🚀 LLM App")
st.write("App is running successfully!")
# Out:
# 2026-03-21 00:27:54.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.483
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\SIBIYA GAMING\miniconda3\envs\myenv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-21 00:27:54.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 00:27:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
